# %%
eboss_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/eboss_data/'
f_dat = eboss_dir + 'eBOSS_ELG_full_ALL_v1_1.dat_sub.fits'

ran_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/'
f_ran = ran_dir + 'randoms_subset_masked_old.fits'

# %%
# %matplotlib inline
import astropy.io.fits as fits
import matplotlib.pyplot as plt

dat = fits.open(f_dat)[1].data
ran = fits.open(f_ran)[1].data
plt.plot(dat['ra'],dat['dec'],'r,')
plt.plot(ran['RA'],ran['DEC'],'b,')
plt.gca().set_xlim((0,45))
# Out:
# (0, 45)

# %%
plt.plot(ran['RA'],ran['DEC'],'b,')
plt.plot(dat['ra'],dat['dec'],'r.')
plt.gca().set_xlim((0,5))
plt.gca().set_ylim((-1,1))
# Out:
# (-1, 1)

# %%
len(ran)
# Out:
# 155243

# %%
len(ran)/len(dat)
# Out:
# 2.792893766303859

# %%
dr5_dat_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/subset/'
f_dr5_dat = dr5_dat_dir + 'dr5_subset_masked_old.fits'

# %%
dr5_dat = fits.open(f_dr5_dat)[1].data
plt.plot(dr5_dat['ra'],dr5_dat['dec'],'r.')
plt.plot(dat['ra'],dat['dec'],'b+')
plt.gca().set_xlim((318,320))
plt.gca().set_ylim((0,1))
# Out:
# (0, 1)

# %%
# !ls /global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/eboss_data/
# Out:
# dat_cut_to_old.py		  eBOSS_ELG_full_ALL_v1_1.dat_sub.fits
# eBOSS_ELG_full_ALL_v1_1.dat.fits  eBOSS_ELG_full_ALL_v1_1.ran.fits

# %%
eboss_dir = '/global/cscratch1/sd/huikong/obiwan_Aug/repos_for_docker/obiwan_out/eboss_data/'
f_dat = eboss_dir + 'eBOSS_ELG_full_ALL_v1_1.ran_sub.fits'
dat = fits.open(f_dat)[1].data
ranfilename = 'eBOSS_ELG_full_ALL_v1_1.ran_sub.fits'

# %%
dat = fits.open(eboss_dir+ranfilename)[1].data

# %%
plt.plot(dat['ra'],dat['dec'],'r,')

# %%
dat = fits.open(eboss_dir+'eBOSS_ELG_full_ALL_v1_1.dat_sub.fits')[1].data
plt.plot(dat['ra'],dat['dec'],'r,')
